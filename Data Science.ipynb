# %%
import numpy as np
import pandas as pd

# %%
data=[1,2,3,4,5]
series=pd.Series(data)

# %%
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series=pd.Series(data,index=['a','b','c','d','e'])
series
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
dic=({'Fruits':['Apple','Banana','Grapes'],'Price':[130,150,100]})
series1=pd.Series(dict)

# %%
series1
# Out:
# 0    <class 'dict'>
# dtype: object

# %%
ser=pd.DataFrame(dic)

# %%
ser
# Out:
#    Fruits  Price
# 0   Apple    130
# 1  Banana    150
# 2  Grapes    100

# %%
dictionary={'Player':['Player1','Player2','Player3'],'Point':[1,2,3],'Title':['Game1','Game2','Game3']}

# %%
series2=pd.DataFrame(dictionary)
series2
# Out:
#     Player  Point  Title
# 0  Player1      1  Game1
# 1  Player2      2  Game2
# 2  Player3      3  Game3

# %%
numpyarray=np.array([[50000,35000],['John','Kami']])
df=pd.DataFrame({'name':numpyarray[1],'salary':numpyarray[0]})
df
# Out:
#    name salary
# 0  John  50000
# 1  Kami  35000

# %% [markdown]
# #Merge

# %%
player=['player1','player2','player3']
point=[1,4,7]
title=['Game1','Game2','Game3']
df1=pd.DataFrame({'player':player,'point':point,'title':title})
df1
# Out:
#     player  point  title
# 0  player1      1  Game1
# 1  player2      4  Game2
# 2  player3      7  Game3

# %%
player=['player1','player5','player7']
power=['punch','kick','Elbow']
title=['Game1','Game5','Game7']
df2=pd.DataFrame({'player':player,'power':power,'title':title})
df2
# Out:
#     player  power  title
# 0  player1  punch  Game1
# 1  player5   kick  Game5
# 2  player7  Elbow  Game7

# %%
df1.merge(df2,on='title',how='inner')
# Out:
#   player_x  point  title player_y  power
# 0  player1      1  Game1  player1  punch

# %%
df1.merge(df2,on='player',how='inner')
# Out:
#     player  point title_x  power title_y
# 0  player1      1   Game1  punch   Game1

# %%
df1.merge(df2,on='player',how='left')
# Out:
#     player  point title_x  power title_y
# 0  player1      1   Game1  punch   Game1
# 1  player2      4   Game2    NaN     NaN
# 2  player3      7   Game3    NaN     NaN

# %%
df1.merge(df2,on='player',how='right')
# Out:
#     player  point title_x  power title_y
# 0  player1    1.0   Game1  punch   Game1
# 1  player5    NaN     NaN   kick   Game5
# 2  player7    NaN     NaN  Elbow   Game7

# %%
df1.merge(df2,on='player',how='outer')
# Out:
#     player  point title_x  power title_y
# 0  player1    1.0   Game1  punch   Game1
# 1  player2    4.0   Game2    NaN     NaN
# 2  player3    7.0   Game3    NaN     NaN
# 3  player5    NaN     NaN   kick   Game5
# 4  player7    NaN     NaN  Elbow   Game7

# %%
player=['player1','player5','player7']
power=['punch','kick','Elbow']
title=['Game1','Game5','Game7']
df4=pd.DataFrame({'player':player,'power':power,'title':title},index=['L2','L3','L4'])
df4
# Out:
#      player  power  title
# L2  player1  punch  Game1
# L3  player5   kick  Game5
# L4  player7  Elbow  Game7

# %%
player=['player1','player2','player3']
point=[1,4,7]
title=['Game1','Game2','Game3']
df3=pd.DataFrame({'player':player,'point':point,'title':title},index=['L1','L2','L3'])
df3
# Out:
#      player  point  title
# L1  player1      1  Game1
# L2  player2      4  Game2
# L3  player3      7  Game3

# %%
pd.concat([df3,df4])
# Out:
#      player  point  title  power
# L1  player1    1.0  Game1    NaN
# L2  player2    4.0  Game2    NaN
# L3  player3    7.0  Game3    NaN
# L2  player1    NaN  Game1  punch
# L3  player5    NaN  Game5   kick
# L4  player7    NaN  Game7  Elbow

# %%
car=pd.read_csv('C:\\Users\\IDEAL COM\\Downloads\\Compressed\\a412dfbd88b3db70b74b-5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1\\a412dfbd88b3db70b74b-5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1\\mtcars.csv')

# %%
car.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
car.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
car.median()
# Out:
# C:\Users\IDEAL COM\AppData\Local\Temp\ipykernel_11024\961299306.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car.median()
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
car.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
car.count()
# Out:
# model    32
# mpg      32
# cyl      32
# disp     32
# hp       32
# drat     32
# wt       32
# qsec     32
# vs       32
# am       32
# gear     32
# carb     32
# dtype: int64

# %%
car=car.rename(columns={"model":'Mdl'})
car
# Out:
#                     Mdl   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
car.qsec.fillna(car.qsec.mean())
# Out:
# 0     16.46
# 1     17.02
# 2     18.61
# 3     19.44
# 4     17.02
# 5     20.22
# 6     15.84
# 7     20.00
# 8     22.90
# 9     18.30
# 10    18.90
# 11    17.40
# 12    17.60
# 13    18.00
# 14    17.98
# 15    17.82
# 16    17.42
# 17    19.47
# 18    18.52
# 19    19.90
# 20    20.01
# 21    16.87
# 22    17.30
# 23    15.41
# 24    17.05
# 25    18.90
# 26    16.70
# 27    16.90
# 28    14.50
# 29    15.50
# 30    14.60
# 31    18.60
# Name: qsec, dtype: float64

# %%
car.drop(columns=['Mdl'])
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
car['cyl']>6
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# Name: cyl, dtype: bool

# %%
df=car[['mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']].corr()

# %%
df
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mdl     32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
car.iloc[:,4]
# Out:
# 0     110
# 1     110
# 2      93
# 3     110
# 4     175
# 5     105
# 6     245
# 7      62
# 8      95
# 9     123
# 10    123
# 11    180
# 12    180
# 13    180
# 14    205
# 15    215
# 16    230
# 17     66
# 18     52
# 19     65
# 20     97
# 21    150
# 22    150
# 23    245
# 24    175
# 25     66
# 26     91
# 27    113
# 28    264
# 29    175
# 30    335
# 31    109
# Name: hp, dtype: int64

# %%
car.iloc[2:6,5:7]
# Out:
#    drat     wt
# 2  3.85  2.320
# 3  3.08  3.215
# 4  3.15  3.440
# 5  2.76  3.460

# %%
car.head(10)
# Out:
#                  Mdl   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
car.iloc[:4,3:7]
# Out:
#     disp   hp  drat     wt
# 0  160.0  110  3.90  2.620
# 1  160.0  110  3.90  2.875
# 2  108.0   93  3.85  2.320
# 3  258.0  110  3.08  3.215

# %%
car.loc[:,'mpg']
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
car.loc[:6,'mpg':'drat']
# Out:
#     mpg  cyl   disp   hp  drat
# 0  21.0    6  160.0  110  3.90
# 1  21.0    6  160.0  110  3.90
# 2  22.8    4  108.0   93  3.85
# 3  21.4    6  258.0  110  3.08
# 4  18.7    8  360.0  175  3.15
# 5  18.1    6  225.0  105  2.76
# 6  14.3    8  360.0  245  3.21

# %%
car['am']=1

# %%
car.head()
# Out:
#                  Mdl   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   1     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   1     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
f=lambda x:x*2
car['am'].apply(f)
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    2
# 16    2
# 17    2
# 18    2
# 19    2
# 20    2
# 21    2
# 22    2
# 23    2
# 24    2
# 25    2
# 26    2
# 27    2
# 28    2
# 29    2
# 30    2
# 31    2
# Name: am, dtype: int64

# %%
car.sort_values(by='cyl')
# Out:
#                     Mdl   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   1
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# ...

# %%
car.sort_values(by='qsec',ascending=False)
# Out:
#                     Mdl   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   1
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   1
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   1
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   1
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# ...

# %%
filter=car['cyl']>=6

# %%
filter_new=car[filter]
filter_new
# Out:
#                     Mdl   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   1
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   1
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   1
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   1
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   1
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   1
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   1
# ...

# %%
filter=(car['cyl']>6) & (car['hp']>300)
filter1=car[filter]
filter1
# Out:
#               Mdl   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8
